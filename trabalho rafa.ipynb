# %%
import networkx as nx

influenciadores = nx.Graph()
qtd_vert = int(input("Quantas pessoas você quer adicionar? "))
for nmr in range(qtd_vert):
    nome_pessoa = input("Qual o nome da pessoa? ").capitalize()
    vertice = int(input(f"Quantos influenciadores o(a) {nome_pessoa} segue? "))

    influenciadores.add_node(nome_pessoa)

    for vertices in range(vertice):
        if vertice >= 0:
            contador = vertices + 1
            nome = input(f"Nome do influenciador N°{contador} que o(a) {nome_pessoa} segue: ").capitalize()
            influenciadores.add_node(nome)
            influenciadores.add_edge(nome_pessoa, nome, weight=1)

numero_vertice = influenciadores.number_of_nodes()
numero_arestas = influenciadores.number_of_edges()
ligacoes = list(influenciadores.edges(data=True))
nomes_vertices = list(influenciadores.nodes)
graus = influenciadores.degree()
acumuladora = sum(dict(graus).values())

print(f"Os graus dos vértices são: {dict(graus)}")
print(f"O grau médio é {acumuladora / influenciadores.number_of_nodes():.2f}")
print(f"Os vértices são: {nomes_vertices}")
print(f"O Grafo possui {numero_vertice} vertices, {numero_arestas} arestas e suas ligações são: {ligacoes}.")
print("Os pesos das arestas são:")
for u, v, wt in influenciadores.edges(data='weight'):
    print(f"({u} -> {v}, peso: {wt})")
contapeso = 0
for p in influenciadores.edges():
  contapeso += wt
print(f"A força de conectividade média é: {contapeso / numero_arestas}")
densidade = (2 * len(ligacoes)) / (numero_vertice * (numero_vertice - 1)) if numero_vertice > 1 else 0
print(f"O grafo possui densidade = {densidade:.2f}")
# Out:
# Quantas pessoas você quer adicionar? 6
# Qual o nome da pessoa? Rafael
# Quantos influenciadores o(a) Rafael segue? 17
# Nome do influenciador N°1 que o(a) Rafael segue: neymar
# Nome do influenciador N°2 que o(a) Rafael segue: luanSantana
# Nome do influenciador N°3 que o(a) Rafael segue: pericles
# Nome do influenciador N°4 que o(a) Rafael segue: profCaio
# Nome do influenciador N°5 que o(a) Rafael segue: profDouglas
# Nome do influenciador N°6 que o(a) Rafael segue: profHenrique
# Nome do influenciador N°7 que o(a) Rafael segue: unimar
# Nome do influenciador N°8 que o(a) Rafael segue: unesp
# Nome do influenciador N°9 que o(a) Rafael segue: anitta
# Nome do influenciador N°10 que o(a) Rafael segue: rihana
# Nome do influenciador N°11 que o(a) Rafael segue: beyonce
# Nome do influenciador N°12 que o(a) Rafael segue: dorivalJr
# Nome do influenciador N°13 que o(a) Rafael segue: fDiniz
# Nome do influenciador N°14 que o(a) Rafael segue: cr7
# Nome do influenciador N°15 que o(a) Rafael segue: messi
# Nome do influenciador N°16 que o(a) Rafael segue: lebronJames
# Nome do influenciador N°17 que o(a) Rafael segue: paulMcCartney
# Qual o nome da pessoa? joao
# Quantos influenciadores o(a) Joao segue? 7
# Nome do influenciador N°1 que o(a) Joao segue: neymar
# Nome do influenciador N°2 que o(a) Joao segue: unimar
# Nome do influenciador N°3 que o(a) Joao segue: unesp
# Nome do influenciador N°4 que o(a) Joao segue: anitta
# Nome do influenciador N°5 que o(a) Joao segue: rihana
# Nome do influenciador N°6 que o(a) Joao segue: fDiniz
# Nome do influenciador N°7 que o(a) Joao segue: profRafael
# Qual o nome da pessoa? Bia
# Quantos influenciadores o(a) Bia segue? 10
# Nome do influenciador N°1 que o(a) Bia segue: beyonce
# Nome do influenciador N°2 que o(a) Bia segue: luanSantana
# Nome do influenciador N°3 que o(a) Bia segue: pericles
# Nome do influenciador N°4 que o(a) Bia segue: profCaio
# Nome do influenciador N°5 que o(a) Bia segue: profDouglas
# Nome do influenciador N°6 que o(a) Bia segue: profHenrique
# Nome do influenciador N°7 que o(a) Bia segue: paulMcCartney
# Nome do influenciador N°8 que o(a) Bia segue: profRafael
# Nome do influenciador N°9 que o(a) Bia segue: beyonce
# Nome do influenciador N°10 que o(a) Bia segue: dorivalJr
# Qual o nome da pessoa? giovana
# Quantos influenciadores o(a) Giovana segue? 3
# Nome do influenciador N°1 que o(a) Giovana segue: cr7
# Nome do influenciador N°2 que o(a) Giovana segue: messi
# Nome do influenciador N°3 que o(a) Giovana segue: profRafael
# Qual o nome da pessoa? caio
# Quantos influenciadores o(a) Caio segue? 8
# Nome do influenciador N°1 que o(a) Caio segue: profCaio
# Nome do influenciador N°2 que o(a) Caio segue: dorivalJr
# Nome do influenciador N°3 que o(a) Caio segue: fDiniz
# Nome do influenciador N°4 que o(a) Caio segue: cr7
# Nome do influenciador N°5 que o(a) Caio segue: messi
# Nome do influenciador N°6 que o(a) Caio segue: lebronJames
# Nome do influenciador N°7 que o(a) Caio segue: rihana
# Nome do influenciador N°8 que o(a) Caio segue: beyonce
# Qual o nome da pessoa? Henrique
# Quantos influenciadores o(a) Henrique segue? 7
# Nome do influenciador N°1 que o(a) Henrique segue: profHenrique
# Nome do influenciador N°2 que o(a) Henrique segue: Unimar
# Nome do influenciador N°3 que o(a) Henrique segue: unesp
# Nome do influenciador N°4 que o(a) Henrique segue: beyonce
# Nome do influenciador N°5 que o(a) Henrique segue: cr7
# Nome do influenciador N°6 que o(a) Henrique segue: lebronJames
# Nome do influenciador N°7 que o(a) Henrique segue: paulMcCartney
# Os graus dos vértices são: {'Rafael': 17, 'Neymar': 2, 'Luansantana': 2, 'Pericles': 2, 'Profcaio': 3, 'Profdouglas': 2, 'Profhenrique': 3, 'Unimar': 3, 'Unesp': 3, 'Anitta': 2, 'Rihana': 3, 'Beyonce': 4, 'Dorivaljr': 3, 'Fdiniz': 3, 'Cr7': 4, 'Messi': 3, 'Lebronjames': 3, 'Paulmccartney': 3, 'Joao': 7, 'Profrafael': 3, 'Bia': 9, 'Giovana': 3, 'Caio': 8, 'Henrique': 7}
# O grau médio é 4.25
# Os vértices são: ['Rafael', 'Neymar', 'Luansantana', 'Pericles', 'Profcaio', 'Profdouglas', 'Profhenrique', 'Unimar', 'Unesp', 'Anitta', 'Rihana', 'Beyonce', 'Dorivaljr', 'Fdiniz', 'Cr7', 'Messi', 'Lebronjames', 'Paulmccartney', 'Joao', 'Profrafael', 'Bia', 'Giovana', 'Caio', 'Henrique']
# O Grafo possui 24 vertices, 51 arestas e suas ligações são: [('Rafael', 'Neymar', {'weight': 1}), ('Rafael', 'Luansantana', {'weight': 1}), ('Rafael', 'Pericles', {'weight': 1}), ('Rafael', 'Profcaio', {'weight': 1}), ('Rafael', 'Profdouglas', {'weight': 1}), ('Rafael', 'Profhenrique', {'weight': 1}), ('Rafael', 'Unimar', {'weight': 1}), ('Rafael', 'Unesp', {'weight': 1}), ('Rafael', 'Anitta', {'weight': 1}), ('Rafael', 'Rihana', {'weight': 1}), ('Rafael', 'Beyonce', {'weight': 1}), ('Rafael', 'Dorivaljr', {'weight': 1}), ('Rafael', 'Fdiniz', {'weight': 1}), ('Rafael', 'Cr7', {'weight': 1}), ('Rafael', 'Messi', {'weight': 1}), ('Rafael', 'Lebronjames', {'weight': 1}), ('Rafael', 'Paulmccartney', {'weight': 1}), ('Neymar', 'Joao', {'weight': 1}), ('Luansantana', 'Bia', {'weight': 1}), ('Pericles', 'Bia', {'weight': 1}), ('Profcaio', 'Bia', {'weight': 1}), ('Profcaio', 'Caio', {'weight': 1}), ('Profdouglas', 'Bia', {'weight': 1}), ('Profhenrique', 'Bia', {'weight': 1}), ('Profhenrique', 'Henrique', {'weight': 1}), ('Unimar', 'Joao', {'weight': 1}), ('Unimar', 'Henrique', {'weight': 1}), ('Unesp', 'Joao', {'weight': 1}), ('Unesp', 'Henrique', {'weight': 1}), ('Anitta', 'Joao', {'weight': 1}), ('Rihana', 'Joao', {'weight': 1}), ('Rihana', 'Caio', {'weight': 1}), ('Beyonce', 'Bia', {'weight': 1}), ('Beyonce', 'Caio', {'weight': 1}), ('Beyonce', 'Henrique', {'weight': 1}), ('Dorivaljr', 'Bia', {'weight': 1}), ('Dorivaljr', 'Caio', {'weight': 1}), ('Fdiniz', 'Joao', {'weight': 1}), ('Fdiniz', 'Caio', {'weight': 1}), ('Cr7', 'Giovana', {'weight': 1}), ('Cr7', 'Caio', {'weight': 1}), ('Cr7', 'Henrique', {'weight': 1}), ('Messi', 'Giovana', {'weight': 1}), ('Messi', 'Caio', {'weight': 1}), ('Lebronjames', 'Caio', {'weight': 1}), ('Lebronjames', 'Henrique', {'weight': 1}), ('Paulmccartney', 'Bia', {'weight': 1}), ('Paulmccartney', 'Henrique', {'weight': 1}), ('Joao', 'Profrafael', {'weight': 1}), ('Profrafael', 'Bia', {'weight': 1}), ('Profrafael', 'Giovana', {'weight': 1})].
# Os pesos das arestas são:
# (Rafael -> Neymar, peso: 1)
# (Rafael -> Luansantana, peso: 1)
# (Rafael -> Pericles, peso: 1)
# (Rafael -> Profcaio, peso: 1)
# (Rafael -> Profdouglas, peso: 1)
# (Rafael -> Profhenrique, peso: 1)
# (Rafael -> Unimar, peso: 1)
# (Rafael -> Unesp, peso: 1)
# (Rafael -> Anitta, peso: 1)
# (Rafael -> Rihana, peso: 1)
# (Rafael -> Beyonce, peso: 1)
# (Rafael -> Dorivaljr, peso: 1)
# (Rafael -> Fdiniz, peso: 1)
# (Rafael -> Cr7, peso: 1)
# (Rafael -> Messi, peso: 1)
# (Rafael -> Lebronjames, peso: 1)
# (Rafael -> Paulmccartney, peso: 1)
# (Neymar -> Joao, peso: 1)
# (Luansantana -> Bia, peso: 1)
# (Pericles -> Bia, peso: 1)
# (Profcaio -> Bia, peso: 1)
# (Profcaio -> Caio, peso: 1)
# (Profdouglas -> Bia, peso: 1)
# (Profhenrique -> Bia, peso: 1)
# (Profhenrique -> Henrique, peso: 1)
# (Unimar -> Joao, peso: 1)
# (Unimar -> Henrique, peso: 1)
# (Unesp -> Joao, peso: 1)
# (Unesp -> Henrique, peso: 1)
# (Anitta -> Joao, peso: 1)
# (Rihana -> Joao, peso: 1)
# (Rihana -> Caio, peso: 1)
# (Beyonce -> Bia, peso: 1)
# (Beyonce -> Caio, peso: 1)
# (Beyonce -> Henrique, peso: 1)
# (Dorivaljr -> Bia, peso: 1)
# (Dorivaljr -> Caio, peso: 1)
# (Fdiniz -> Joao, peso: 1)
# (Fdiniz -> Caio, peso: 1)
# (Cr7 -> Giovana, peso: 1)
# (Cr7 -> Caio, peso: 1)
# (Cr7 -> Henrique, peso: 1)
# (Messi -> Giovana, peso: 1)
# (Messi -> Caio, peso: 1)
# (Lebronjames -> Caio, peso: 1)
# (Lebronjames -> Henrique, peso: 1)
# (Paulmccartney -> Bia, peso: 1)
# (Paulmccartney -> Henrique, peso: 1)
# (Joao -> Profrafael, peso: 1)
# (Profrafael -> Bia, peso: 1)
# (Profrafael -> Giovana, peso: 1)
# A força de conectividade média é: 1.0
# O grafo possui densidade = 0.18

# %% [markdown]
# exemplo Twitter
# Rafael  Joao    Bia Giovana Caio    Henrique
# @neymar @neymar @Beyonce    @ProfCaio   @profRafael @ProfCaio
# @LuanSantana    @LuanSantana    @DorivalJr  @ProfDouglas    @profHenrique   @profHenrique
# @Pericles   @Pericles   @FDiniz @profHenrique   @Unimar @profRafael
# @ProfCaio   @ProfCaio   @Cr7    @Unimar @Unesp  @Unimar
# @ProfDouglas    @ProfDouglas    @Messi  @Unesp  @Anitta @Unesp
# @profHenrique   @profHenrique   @LebronJames    @Anitta @Rihana @Anitta
# @Unimar @Unimar @PaulMcCartney  @Rihana @Beyonce    @Rihana
# @Unesp  @Unesp  @profRafael @Beyonce    @Cr7    @Beyonce
# @Anitta @Anitta     @Cr7    @Messi  @Cr7
# @Rihana @Rihana     @Messi  @LebronJames    @Messi
# @Beyonce    @Beyonce        @LebronJames        @LebronJames
# @DorivalJr  @DorivalJr      @PaulMcCartney
# @FDiniz @FDiniz     @profRafael
# @Cr7    @profRafael
# @Messi
# @LebronJames
# @PaulMcCartney
